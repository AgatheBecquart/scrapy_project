# %%
import pandas as pd

# %%
df = pd.read_csv('top_series.csv')

# %%
df
# Out:
#                           title original_title  score
# 0               Planet Earth II            NaN    9.5  \
# 1                  Breaking Bad            NaN    9.5
# 2                  Planet Earth            NaN    9.4
# 3              Band of Brothers            NaN    9.4
# 4               Hunter x Hunter            NaN    9.0
# ..                          ...            ...    ...
# 245                The Sopranos            NaN    9.2
# 246              Blue Planet II            NaN    9.3
# 247  Avatar: The Last Airbender            NaN    9.3
# 248                    The Wire            NaN    9.3
# 249                   Chernobyl            NaN    9.4
#
#                           genre       year
# 0                   Documentary       2016  \
# 1          Crime,Drama,Thriller  2008–2013
# 2                   Documentary       2006
# 3             Drama,History,War       2001
# 4    Animation,Action,Adventure  2011–2014
# ..                          ...        ...
# ...

# %%
print(df.loc[116, 'original_title'])
# Out:
# Original title: Sa-rang-eui bul-shi-chak
