# %%
import pandas as pd

# %%
df = pd.read_csv('top_films.csv')

# %%
df
# Out:
#                         titre              titre original  year  note
# 0    The Shawshank Redemption                         NaN  1994   9.3  \
# 1               The Godfather                         NaN  1972   9.2
# 2             The Dark Knight                         NaN  2008   9.0
# 3       The Godfather Part II                         NaN  1974   9.0
# 4                Pulp Fiction                         NaN  1994   8.9
# ..                        ...                         ...   ...   ...
# 245                Goodfellas  Original title: GoodFellas  1990   8.7
# 246                The Matrix                         NaN  1999   8.7
# 247              Forrest Gump                         NaN  1994   8.8
# 248          Schindler's List                         NaN  1993   9.0
# 249              12 Angry Men                         NaN  1957   9.0
#
#                        genre  duree
# 0                      Drama    142  \
# 1                Crime,Drama    175
# ...

# %%
print(df.loc[116, 'original_title'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'original_title'
#
# The above exception was the direct cause of the following exception:
#
# ...
